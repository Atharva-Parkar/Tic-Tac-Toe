# %%
tictac = [" ", " ", " ", " ", " ", " ", " ", " ", " "]
print("Indices for placement")
for i in range(1, 10):
    if i % 3 != 0:
        print(str(i) + " |", end=" ")
    elif i != 9:
        print(i)
        print('--+---+--')
    else:
        print(i)

print()
def Printing():
    for i in range(0, 9):
        if (i + 1) % 3 != 0:
            print(tictac[i] + " |", end=" ")
        elif (i + 1) != 9:
            print(tictac[i])
            print('--+---+--')
        else:
            print(tictac[i])
Printing()

def game():
    check = 0
    count = 0
    while check == 0:
        if count % 2 == 0:
            print("It's your turn X. Where to place?")
            n = int(input())
            if tictac[n-1] == " ":
                tictac[n-1] = "X"
                count += 1
            else:
                print("Cannot place here.")
                continue
        else:
            print("It's your turn O. Where to place?")
            n = int(input())
            if tictac[n-1] == " ":
                tictac[n-1] = "O"
                count += 1
            else:
                print("Cannot place here.")
                continue
        Printing()
        if count == 9:
            print("It's a draw!")
            break
        elif count >= 5:
            if tictac[0] == tictac[1] == tictac[2] and tictac[0] != " ":
                if tictac[0] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            elif tictac[3] == tictac[4] == tictac[5] and tictac[3] != " ":
                if tictac[3] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            elif tictac[6] == tictac[7] == tictac[8] and tictac[6] != " ":
                if tictac[6] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            elif tictac[0] == tictac[3] == tictac[6] and tictac[0] != " ":
                if tictac[0] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            elif tictac[1] == tictac[4] == tictac[7] and tictac[1] != " ":
                if tictac[1] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            elif tictac[2] == tictac[5] == tictac[8] and tictac[2] != " ":
                if tictac[2] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            elif tictac[0] == tictac[4] == tictac[8] and tictac[0] != " ":
                if tictac[0] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            elif tictac[2] == tictac[4] == tictac[6] and tictac[2] != " ":
                if tictac[2] == "X":
                    print("X has won the game.")
                else:
                    print("O has won the game.")
                check = 1
            else:
                continue
game()
# Out:
# Indices for placement
# 1 | 2 | 3
# --+---+--
# 4 | 5 | 6
# --+---+--
# 7 | 8 | 9
#
#   |   |
# --+---+--
#   |   |
# --+---+--
#   |   |
# It's your turn X. Where to place?
